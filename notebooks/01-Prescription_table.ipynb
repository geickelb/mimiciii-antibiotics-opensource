# %% [markdown]
# ## code for generating ATC codes from rxcui and NDC
# ultimate goal: We want a list of all antibiotics prescribed in the prescription table that would be prescribed if the physician suspected the patient of having a serious bacterial infection

# %% [markdown]
# * ATC codes are obtained via two step conversion:
#  * national drug codes (NDC) found in the PRESCRIPTION table of the MIMIC-III dataset -> RxNorm concept unique identifier (RXCUI) codes.
#  * -> RXCUI codes into ATC codes.
#
# * ATC codes with prefix 'J01' are considered to be antibiotics.
# * Regular expressions were used on prescription names to further filter out erroneous entries and entries with missing NDC/RXCUI codes.
#  * note: the text analysis via manual review and regular expressions is located in __. in this notebook, all erroneous values are hardcoded in a list to filter out.

# %%
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import psycopg2
import collections
import asyncio
import getpass
import re
from datetime import datetime as dt
import os,sys,re
import urllib3
import prettytable
from collections import Counter
import seaborn as sns
import random

# %matplotlib inline
plt.style.use('ggplot')

from notebook.services.config import ConfigManager
cm = ConfigManager()
cm.update('livereveal', {
        'width': 1024,
        'height': 768,
        'scroll': True,
})

# %load_ext autotime

# %% [markdown]
# ## Fetch all responses within one Client session first

# %%
import asyncio
from aiohttp import ClientSession
import time
import json

async def fetch(url, session):
    async with session.get(url) as response:
        return await response.read()

async def run(url_lst):
    tasks = []

    # Fetch all responses within one Client session,
    # keep connection alive for all requests.
    start = time.perf_counter()
    
    async with ClientSession() as session:
        for url in url_lst:
            task = asyncio.ensure_future(fetch(url, session))
            tasks.append(task)

        responses = await asyncio.gather(*tasks)
        # you now have all response bodies in this variable
#         print(responses)

    duration = time.perf_counter() - start
    print('total time: {}'.format(duration))
    return responses
# Out:
# time: 175 ms

# %% [markdown]
# ## Access MIMIC database and convert it to dataframe in Pandas

# %%
# note, all server information is stored in a config.py file that is present in the .gitignore
import config 
conn = psycopg2.connect(dbname=config.dbname, user=config.user, host=config.host, port=config.port,password=config.password)
cur=conn.cursor()

query_schema = 'SET search_path to ' + "mimiciii" + ';'
# Out:
# time: 146 ms

# %% [markdown]
# ## Prescription
# * grabbing the entire prescription table from MIMIC

# %%
#code for generating ATC codes from rxcui and NDC
# Out:
# time: 590 µs

# %%
cur.execute('Select * from mimiciii.prescriptions')
rows = cur.fetchall()
# Out:
# time: 38min 23s

# %%
col_name = []
for i in range(len(cur.description)):
    col_name.append(cur.description[i][0])
print (col_name)
# Out:
# ['row_id', 'subject_id', 'hadm_id', 'icustay_id', 'startdate', 'enddate', 'drug_type', 'drug', 'drug_name_poe', 'drug_name_generic', 'formulary_drug_cd', 'gsn', 'ndc', 'prod_strength', 'dose_val_rx', 'dose_unit_rx', 'form_val_disp', 'form_unit_disp', 'route']
# time: 2.37 ms

# %%
prescriptionTable = pd.DataFrame(rows,columns=col_name)
# Out:
# time: 21.8 s

# %%
prescriptionTable.head(10)
# Out:
#     row_id  subject_id  hadm_id  icustay_id  startdate    enddate drug_type  \
# 0  2065012       17932   146366         NaN 2116-09-22 2116-09-25      MAIN
# 1  2065010       17932   146366         NaN 2116-09-23 2116-09-21      MAIN
# 2  2065708       17932   146366         NaN 2116-09-23 2116-09-24      MAIN
# 3  2480732       17947   193730    284413.0 2110-07-10 2110-07-10      MAIN
# 4  2480731       17947   193730    284413.0 2110-07-10 2110-07-10      MAIN
# 5  2480733       17947   193730    284413.0 2110-07-10 2110-07-10      MAIN
# 6  2480734       17947   193730    284413.0 2110-07-10 2110-07-10      MAIN
# 7  2480749       17947   193730    284413.0 2110-07-10 2110-07-10      MAIN
# 8  2480752       17947   193730    284413.0 2110-07-10 2110-07-11      MAIN
# 9  2480753       17947   193730    284413.0 2110-07-10 2110-07-11      MAIN
#
#                       drug            drug_name_poe        drug_name_generic  \
# 0        Enoxaparin Sodium        Enoxaparin Sodium        Enoxaparin Sodium
# 1        Enoxaparin Sodium        Enoxaparin Sodium        Enoxaparin Sodium
# 2  Oxycodone-Acetaminophen  Oxycodone-Acetaminophen  Oxycodone-Acetaminophen
# 3               Metoprolol               Metoprolol               Metoprolol
# 4               Metoprolol               Metoprolol               Metoprolol
# 5               Furosemide               Furosemide               Furosemide
# 6           Metoclopramide           Metoclopramide       Metoclopramide HCl
# 7               Metoprolol               Metoprolol               Metoprolol
# 8               Metoprolol               Metoprolol               Metoprolol
# 9               Metoprolol               Metoprolol               Metoprolol
#
#   formulary_drug_cd     gsn          ndc  prod_strength dose_val_rx  \
# 0           LOVE40I  039482  00075062040   40mg Syringe          40
# 1           LOVE40I  039482  00075062040   40mg Syringe          40
# 2              PERC  004222  00054465025  5mg/325mg Tab         1-2
# 3            METO25  050631  51079025520    25mg Tablet          25
# 4            METO5I  019808  55390007310   5mg/5mL Vial         2.5
# 5           FURO40I  008205  00409610204  40mg/4mL Vial          20
# 6           METO10I  005229  60977045101     5mg/mL-2mL           5
# 7            METO25  050631  51079025520    25mg Tablet        12.5
# 8            METO25  050631  51079025520    25mg Tablet          25
# 9            METO25  050631  51079025520    25mg Tablet          25
#
#   dose_unit_rx form_val_disp form_unit_disp route
# 0           mg             1            SYR    SC
# 1           mg             1            SYR    SC
# 2          TAB           1-2            TAB    PO
# 3           mg             1            TAB    PO
# 4           mg           0.5           VIAL    IV
# 5           mg           0.5           VIAL    IV
# 6           mg           0.5           VIAL    IV
# 7           mg           0.5            TAB    PO
# 8           mg             1            TAB    PO
# 9           mg             1            TAB    PO
# time: 167 ms

# %% [markdown]
# ## Convert NDC to Rxcui and add it in to prescription table
# * must ping nlm url to do this.

# %%
ndc_lst = prescriptionTable['ndc'].unique()
url_lst = [#'http://rxnav.nlm.nih.gov/REST/rxcui.json?idtype=NDC&id={0}'.format(ndc)
           'https://rxnav.nlm.nih.gov/REST/ndcstatus.json?ndc={0}'.format(ndc)
           for ndc in ndc_lst]

loop = asyncio.get_event_loop()
future = asyncio.ensure_future(run(url_lst))
responses = loop.run_until_complete(future)
# Out:
# total time: 255.66725896304706
# time: 4min 16s

# %%
#rxcui
def get_rxnormId_by_ndc(response):
    try:
        #class_lst = [x['rxclassMinConceptItem']['classId'] for x in json.loads(response)['rxclassDrugInfoList']['rxclassDrugInfo']]
        return json.loads(response)['ndcStatus']['rxcui']
    except:
        return ''
# Out:
# time: 2.12 ms

# %%
Rx_code_lst = [get_rxnormId_by_ndc(resp) for resp in responses] #list of rxnorm_codes

#making a dictionary of mappings for ndc_code: rxcui
ndc_rc_code_lst_map = {ndc: rx for ndc, rx in zip(ndc_lst, Rx_code_lst)}
# Out:
# time: 56.4 ms

# %%
##make a column that mapps the NDC code to RXCUI
prescriptionTable = prescriptionTable.assign(rxcui = prescriptionTable['ndc'].map(ndc_rc_code_lst_map))
# Out:
# time: 3.53 s

# %% [markdown]
# ## Convert Rxcui to ATC and check whether the drug is Anibiotics, and add it into table

# %%
rxcui_lst = prescriptionTable['rxcui'].unique()
url_lst = ['https://rxnav.nlm.nih.gov/REST/rxclass/class/byRxcui.json?rxcui={}&relaSource=ATC'.format(rxcui)
           for rxcui in rxcui_lst]

loop = asyncio.get_event_loop()
future = asyncio.ensure_future(run(url_lst))
responses = loop.run_until_complete(future)
# Out:
# total time: 181.71388792601647
# time: 3min 1s

# %%
def get_ATC_code_lst(response):
    try:
        class_lst = [x['rxclassMinConceptItem']['classId'] for x in json.loads(response)['rxclassDrugInfoList']['rxclassDrugInfo']]
        return class_lst
    except:
        return []

ATC_code_lst_lst = [get_ATC_code_lst(resp) for resp in responses]

#qc to check it works
pd.DataFrame({'rxcui': rxcui_lst,
                   'ATC_code_lst': ATC_code_lst_lst}).head(5)
# Out:
# time: 66.1 ms

# %%
ab_lst = [any(map(lambda x: x.startswith('J01'), ATC_code_lst)) 
           for ATC_code_lst in ATC_code_lst_lst]

#qc to check it works
pd.DataFrame({'rxcui': rxcui_lst,
                   'ATC_code_lst': ATC_code_lst_lst,
                   'ab': ab_lst}).head(10)
# Out:
#      rxcui                         ATC_code_lst     ab
# 0   854236                              [B01AB]  False
# 1  1050490                       [N02BE, N02AA]  False
# 2   866924                              [C07AB]  False
# 3   866508                              [C07AB]  False
# 4  1719291                              [C03CA]  False
# 5   207263                                   []  False
# 6  1658221  [A06AD, A12CC, B05XA, D11AX, V04CC]  False
# 7   630208                       [R03AC, R03CC]  False
# 8  1807508                       [A07AA, J01XA]   True
# 9   201828                                   []  False
# time: 15.2 ms

# %%
ab_map = {rxcui: ab for rxcui, ab in zip(rxcui_lst, ab_lst)}

prescriptionTable = prescriptionTable.assign(Antibiotics = prescriptionTable['rxcui'].map(ab_map))
# Out:
# time: 2.57 ms

# %%
# this is the end result of code present in: https://github.com/geickelb/Abx_patients_outcome
# As part of a class project, our group performed some review of all antibiotics present in the prescriptionTable with antibiotic==True (based on the ATC code).
# the review involved manual review and regular expressions to identify and filter out any unwanted antibiotics in our dataset. 

#some rows in AB have the same drug name, but differing true/false ab status. this is updating any antibiotic row as true.

#input: imported prescription df annotated with atc codes. 
#ouput: updated prescription df where more true antibiotics are covered

def prescription_update_fxn(prescription_df):
    """
    this function:
    some rows in AB have the same drug name, but differing true/false ab status. this is updating any antibiotic row as true.
    Additionally, there are drugs with antibiotics==True that are not desired for our uses. We want antibiotics that would be prescribed if the physician suspected the patient of having a serious bacterial infection
    
    input: imported prescription df annotated with atc codes. 
    ouput: updated prescription df where more true antibiotics are covered

    """
    drugs_that_dont_belong =['Furosemide','Dextrose 50%','Vancomycin Oral Liquid',
                     'Erythromycin 0.5% Ophth Oint','NEO*IV*Furosemide',
                     'Nystatin','Orthopedic Solution','Neomycin-Polymyxin-Bacitracin Ophth. Oint',
                     'Bacitracin Ophthalmic Oint','Bacitracin Ointment','Lasix',
                     'dextrose','MetronidAZOLE Topical 1 % Gel','Enalaprilat',
                     'NEO*PO*Furosemide (10mg/1ml)','Metronidazole Gel 0.75%-Vaginal','Spironolactone',
                     'Heparin',
                    'voriconazole','valgancyclovir','chloroquine','tamiflu','mefloquine','foscarnet',
                     'fluconazole','vorconazole','quinine','ribavirin','gancyclovir','chloroquine',
                     'atovaquone','ambisome', 'acyclovir', 'Acyclovir']

    drugs_that_dont_belong=[w.lower() for w in drugs_that_dont_belong]
    
    prescriptions= prescription_df
    prescriptions_updated = list(prescriptions.loc[prescriptions.loc[:,"Antibiotics"]==True,'drug'].unique()) 
    true_ndc= prescriptions.loc[prescriptions.loc[:,"drug"].isin(prescriptions_updated),'ndc'].unique() 

    ABrx2= prescriptions.loc[prescriptions.loc[:,"ndc"].isin(true_ndc),:]
    ABrx2= ABrx2.loc[~ABrx2.loc[:,"drug"].str.lower().isin(drugs_that_dont_belong),:] #tilde transforms isin to notin()
    ABrx2['Antibiotics']= True
    return(ABrx2)
# Out:
# time: 23.4 ms

# %%
#this code takes a while to run, only run if need to update prescription table (which is saved in github)
#note shown: imported antibiotic annotations into prescription table using code provided by
#Dr. Luo's postdoc, which pings API
dtype = {'icustay_id': str,
         'NDC': str,
         'rxcui': str,
         'ingredient': str}
#prescriptions = pd.read_csv('/Users/geickelb1/Desktop/PhD_Misc/HSIP_442_Yuan_Lao/project/Newprescription.csv', index_col=0, dtype=dtype)

#problem: some rows in AB have the same drug name, but differing true/false ab status. this is updating any antibiotic row as true.


ABrx = prescription_update_fxn(prescriptionTable)
ABrx = ABrx.loc[ABrx['Antibiotics'] == True, :]

#save csv:
#pd.DataFrame(ABrx).to_csv('/Users/geickelb1/Documents/GitHub/mimiciii-antibiotics-modeling/data/raw/csv/02082018_ABrx_updated.csv')
# Out:
# time: 2.21 s

# %%
ABrx
# Out:
#           row_id  subject_id  hadm_id  icustay_id  startdate    enddate  \
# 32       2089125           9   150750      220597 2149-11-10 2149-11-11
# 35       2968761           2   163353      243653 2138-07-18 2138-07-20
# 37       2968762           2   163353      243653 2138-07-18 2138-07-21
# 53       1213116           4   185777      294638 2191-03-16 2191-03-22
# 65       1213118           4   185777      294638 2191-03-17 2191-03-18
# 71       1213119           4   185777      294638 2191-03-18 2191-03-20
# 137       616184          12   112213      232669 2104-08-08 2104-08-09
# 165       616190          12   112213      232669 2104-08-11 2104-08-11
# 176       616851          12   112213      232669 2104-08-12 2104-08-12
# 179       616192          12   112213      232669 2104-08-12 2104-08-13
# 180       616852          12   112213      232669 2104-08-12 2104-08-14
# 191       616856          12   112213      232669 2104-08-14 2104-08-15
# 209      1388226          21   109451      217847 2134-09-13 2134-09-20
# 254      1379358          21   111970      216859 2135-01-31 2135-01-31
# 326      2089126           9   150750      220597 2149-11-10 2149-11-15
# 333      2089134           9   150750      220597 2149-11-11 2149-11-15
# 355      1992197          10   184167      288409 2103-06-28 2103-07-02
# 358      1992198          10   184167      288409 2103-06-29 2103-07-02
# 423      2350264          25   129635      203487 2160-11-02 2160-11-04
# 425      2350266          25   129635      203487 2160-11-02 2160-11-04
# 472      1379346          21   111970      216859 2135-01-31 2135-02-01
# 473      1379345          21   111970      216859 2135-01-31 2135-02-01
# 481       711036          17   161087      257980 2135-05-10 2135-05-11
# 574      1388217          21   109451      217847 2134-09-12 2134-09-13
# 622      1136932          23   124321      234044 2157-10-21 2157-10-25
# 644      1136931          23   124321      234044 2157-10-21 2157-10-22
# 687      2907884          35   166707      282039 2122-02-13 2122-02-14
# 688      2907885          35   166707      282039 2122-02-13 2122-02-15
# 838      2381502          27   134931      298615 2191-12-01 2191-12-03
# 841      2381503          27   134931      298615 2191-12-01 2191-12-03
# ...          ...         ...      ...         ...        ...        ...
# 2708414  3998126       98887   184321      286283 2144-09-18 2144-09-18
# 2708415  3998127       98887   184321      286283 2144-09-18 2144-09-18
# 2708429  3998130       98887   184321      286283 2144-09-18 2144-09-19
# 2708430  3998128       98887   184321      286283 2144-09-18 2144-09-19
# 2708431  3998123       98887   184321      286283 2144-09-18 2144-09-19
# 2708432  3998124       98887   184321      286283 2144-09-18 2144-09-19
# 2708433  3717817       98959   116420      298632 2142-01-06 2142-01-06
# 2708434  3717816       98959   116420      298632 2142-01-06 2142-01-06
# 2708485  2917706       98994   161559      253953 2138-07-03 2138-07-04
# 2708514  3861092       99955   108494      243255 2139-07-17 2139-07-18
# 2708530  3861093       99955   108494      243255 2139-07-18 2139-07-19
# 2708540   155798       99957   148574      257127 2157-02-21 2157-02-21
# 2708544   155800       99957   148574      257127 2157-02-21 2157-02-21
# 2708546   155616       99957   148574      257127 2157-02-21 2157-02-21
# 2708547   155799       99957   148574      257127 2157-02-21 2157-02-21
# 2708550   155615       99957   148574      257127 2157-02-21 2157-02-21
# 2708551   155617       99957   148574      257127 2157-02-21 2157-02-22
# 2708563  3998129       98887   184321      286283 2144-09-18 2144-09-21
# 2708564  3998132       98887   184321      286283 2144-09-18 2144-09-21
# 2708567  3998125       98887   184321      286283 2144-09-18 2144-09-25
# 2708583  3998136       98887   184321      286283 2144-09-21 2144-09-21
# 2708594   845279       98931   185895      262501 2166-05-04 2166-05-05
# 2708595   845278       98931   185895      262501 2166-05-04 2166-05-06
# 2708596   845280       98931   185895      262501 2166-05-04 2166-05-06
# 2708599   845281       98931   185895      262501 2166-05-04 2166-05-07
# 2708648  2922163       98994   178949      256008 2137-08-13 2137-08-13
# 2708660  2922164       98994   178949      256008 2137-08-14 2137-08-15
# 2708664  2922166       98994   178949      256008 2137-08-15 2137-08-15
# 2708678  3327274       98995   123142      223471 2155-10-05 2155-10-06
# 2708684   155801       99957   148574      257127 2157-02-21 2157-02-23
#
#         drug_type                           drug  \
# 32           MAIN                   Levofloxacin
# 35           MAIN              NEO*IV*Gentamicin
# 37           MAIN              Ampicillin Sodium
# 53           MAIN                    Clindamycin
# 65           MAIN                 Vancomycin HCl
# 71           MAIN                 Vancomycin HCl
# 137          MAIN                  Metronidazole
# 165          MAIN                  Metronidazole
# 176          MAIN     Piperacillin-Tazobactam Na
# 179          MAIN     Piperacillin-Tazobactam Na
# 180          MAIN     Piperacillin-Tazobactam Na
# 191          MAIN     Piperacillin-Tazobactam Na
# 209          MAIN                   Levofloxacin
# 254          MAIN                      Meropenem
# 326          MAIN                  Metronidazole
# 333          MAIN                   Levofloxacin
# 355          MAIN       NEO*IV*Ampicillin Sodium
# 358          MAIN              NEO*IV*Gentamicin
# 423          MAIN                  Metronidazole
# 425          MAIN                    Ceftazidime
# 472          MAIN                 Vancomycin HCl
# 473          MAIN                      Meropenem
# 481          MAIN                 Vancomycin HCl
# 574          MAIN                   Levofloxacin
# 622          MAIN                     Vancomycin
# 644          MAIN                     Vancomycin
# 687          MAIN                 Vancomycin HCl
# 688          MAIN                 Vancomycin HCl
# 838          MAIN              NEO*IV*Gentamicin
# 841          MAIN       NEO*IV*Ampicillin Sodium
# ...           ...                            ...
# 2708414      MAIN               Ciprofloxacin IV
# 2708415      MAIN                     Vancomycin
# 2708429      MAIN                     Vancomycin
# 2708430      MAIN                       CefePIME
# 2708431      MAIN               Ciprofloxacin IV
# 2708432      MAIN         MetRONIDAZOLE (FLagyl)
# 2708433      MAIN                     Vancomycin
# 2708434      MAIN                      CefazoLIN
# 2708485      MAIN                     Vancomycin
# 2708514      MAIN                     Vancomycin
# 2708530      MAIN                     Vancomycin
# 2708540      MAIN         Penicillin G Potassium
# 2708544      MAIN     Piperacillin-Tazobactam Na
# 2708546      MAIN  Ciprofloxacin 0.3% Ophth Soln
# 2708547      MAIN     Piperacillin-Tazobactam Na
# 2708550      MAIN  Ciprofloxacin 0.3% Ophth Soln
# 2708551      MAIN  Ciprofloxacin 0.3% Ophth Soln
# 2708563      MAIN                     Vancomycin
# 2708564      MAIN                    CeftriaXONE
# 2708567      MAIN         MetRONIDAZOLE (FLagyl)
# 2708583      MAIN                     Vancomycin
# 2708594      MAIN                      Meropenem
# 2708595      MAIN                     Vancomycin
# 2708596      MAIN                      Meropenem
# 2708599      MAIN                      Meropenem
# 2708648      MAIN                     Vancomycin
# 2708660      MAIN                     Vancomycin
# 2708664      MAIN                     Vancomycin
# 2708678      MAIN                      CefazoLIN
# 2708684      MAIN         MetRONIDAZOLE (FLagyl)
#
#                          drug_name_poe              drug_name_generic  ...  \
# 32                        Levofloxacin                   Levofloxacin  ...
# 35                                None                           None  ...
# 37                                None                           None  ...
# 53                                None                           None  ...
# 65                                None                           None  ...
# 71                                None                           None  ...
# 137                               None                           None  ...
# 165                               None                           None  ...
# 176                               None                           None  ...
# 179                               None                           None  ...
# 180                               None                           None  ...
# 191                               None                           None  ...
# 209                       Levofloxacin                   Levofloxacin  ...
# 254                               None                           None  ...
# 326                      Metronidazole                  Metronidazole  ...
# 333                       Levofloxacin                   Levofloxacin  ...
# 355                               None                           None  ...
# 358                               None                           None  ...
# 423                               None                           None  ...
# 425                               None                           None  ...
# 472                               None                           None  ...
# 473                               None                           None  ...
# 481                               None                           None  ...
# 574                       Levofloxacin                   Levofloxacin  ...
# 622                               None                           None  ...
# 644                               None                           None  ...
# 687                               None                           None  ...
# 688                               None                           None  ...
# 838                               None                           None  ...
# 841                               None                           None  ...
# ...                                ...                            ...  ...
# 2708414                           None                           None  ...
# 2708415                           None                           None  ...
# 2708429                           None                           None  ...
# 2708430                           None                           None  ...
# 2708431                           None                           None  ...
# 2708432                           None                           None  ...
# 2708433                           None                           None  ...
# 2708434                           None                           None  ...
# 2708485                           None                           None  ...
# 2708514                           None                           None  ...
# 2708530                           None                           None  ...
# 2708540                           None                           None  ...
# 2708544                           None                           None  ...
# 2708546  Ciprofloxacin 0.3% Ophth Soln  Ciprofloxacin 0.3% Ophth Soln  ...
# 2708547                           None                           None  ...
# 2708550  Ciprofloxacin 0.3% Ophth Soln  Ciprofloxacin 0.3% Ophth Soln  ...
# 2708551  Ciprofloxacin 0.3% Ophth Soln  Ciprofloxacin 0.3% Ophth Soln  ...
# 2708563                           None                           None  ...
# 2708564                           None                           None  ...
# 2708567                           None                           None  ...
# 2708583                           None                           None  ...
# 2708594                           None                           None  ...
# 2708595                           None                           None  ...
# 2708596                           None                           None  ...
# 2708599                           None                           None  ...
# 2708648                           None                           None  ...
# 2708660                           None                           None  ...
# 2708664                           None                           None  ...
# 2708678                           None                           None  ...
# 2708684                           None                           None  ...
#
#                 prod_strength dose_val_rx   dose_unit_rx form_val_disp  \
# 32                  500mg Tab         500             mg             1
# 35                10mg/mL-2mL        15.5             mg         0.775
# 37                 500mg Vial         500             mg             1
# 53               600mg Premix         600             mg             1
# 65                 500mg Vial         750             mg           1.5
# 71                 500mg Vial         750             mg           1.5
# 137          500mg Premix Bag         500             mg             1
# 165          500mg Premix Bag         500             mg             1
# 176           4.5g Frozen Bag         4.5             gm             1
# 179           4.5g Frozen Bag         4.5             gm             1
# 180           4.5g Frozen Bag         4.5             gm             1
# 191           4.5g Frozen Bag         4.5             gm             1
# 209              250mg Tablet         250             mg             1
# 254                500mg Vial         500             mg             1
# 326                 500MG TAB         500             mg             1
# 333                 250mg Tab         250             mg             1
# 355                500mg Vial         200             mg           0.4
# 358               10mg/mL-2mL           4             mg           0.4
# 423          500mg Premix Bag         500             mg             1
# 425             1g Frozen Bag           1             gm             1
# 472             1g Frozen Bag        1000             mg             1
# 473                500mg Vial         500             mg             1
# 481             1g Frozen Bag        1000             mg             1
# 574              250mg Tablet         250             mg             1
# 622             1g Frozen Bag        1000             mg             1
# 644             1g Frozen Bag        1000             mg             1
# 687             1g Frozen Bag        1000             mg             1
# 688             1g Frozen Bag        1000             mg             1
# 838               10mg/mL-2mL          13             mg           1.3
# 841                500mg Vial         500             mg             1
# ...                       ...         ...            ...           ...
# 2708414      400mg Premix Bag         400             mg             1
# 2708415         1g Frozen Bag        1000             mg             1
# 2708429         1g Frozen Bag        1000             mg             1
# 2708430               2g Vial           2              g            10
# 2708431      400mg Premix Bag         400             mg             1
# 2708432      500mg Premix Bag         500             mg             1
# 2708433         1g Frozen Bag        1000             mg             1
# 2708434         10g Bulk vial           2              g             2
# 2708485            500mg Vial        1250             mg           2.5
# 2708514         1g Frozen Bag        1000             mg             1
# 2708530         1g Frozen Bag        1000             mg             1
# 2708540  20 Million Unit Vial           4  million units             4
# 2708544      4.5 g Frozen Bag         4.5              g             1
# 2708546  2.5mL Dropper Bottle           4           DROP          0.04
# 2708547      4.5 g Frozen Bag         4.5              g             1
# 2708550  2.5mL Dropper Bottle           2           DROP          0.02
# 2708551  2.5mL Dropper Bottle        4-10           DROP      0.04-0.1
# 2708563         1g Frozen Bag        1000             mg             1
# 2708564         2g Frozen Bag           2             gm             1
# 2708567      500mg Premix Bag         500             mg             1
# 2708583         1g Frozen Bag        1000             mg             1
# 2708594           1000mg Vial        1000             mg             1
# 2708595         1g Frozen Bag        1000             mg             1
# 2708596            500mg Vial         500             mg             1
# 2708599            500mg Vial         500             mg             1
# 2708648         1g Frozen Bag        1000             mg             1
# 2708660         1g Frozen Bag        1000             mg             1
# 2708664         1g Frozen Bag        1000             mg             1
# 2708678           1g Froz.Bag           1              g             1
# 2708684      500mg Premix Bag         500             mg             1
#
#         form_unit_disp      route    rxcui Antibiotics   rxcui2 Antibiotics2
# 32                 TAB         NG   211816        True   211816         True
# 35                VIAL         IV  1870676        True  1870676         True
# 37                VIAL         IV  1721474        True  1721474         True
# 53                 BAG         IV   685578        True   685578         True
# 65                VIAL         IV  1807516        True  1807516         True
# 71                VIAL         IV  1807516        True  1807516         True
# 137                BAG         IV   311683        True   311683         True
# 165                BAG         IV   311683        True   311683         True
# 176                BAG         IV   884254        True   884254         True
# 179                BAG         IV   884254        True   884254         True
# 180                BAG         IV   884254        True   884254         True
# 191                BAG         IV   884254        True   884254         True
# 209                TAB         PO   211815        True   211815         True
# 254               VIAL         IV  1722937        True  1722937         True
# 326                TAB         NG   311681        True   311681         True
# 333                TAB         NG   211815        True   211815         True
# 355               VIAL         IV  1721474        True  1721474         True
# 358                 ml         IV   239204        True   239204         True
# 423                BAG         IV   311683        True   311683         True
# 425                BAG         IV  1659285        True  1659285         True
# 472                BAG         IV  1807508        True  1807508         True
# 473               VIAL         IV  1722937        True  1722937         True
# 481                BAG         IV  1807508        True  1807508         True
# 574                TAB         PO   211815        True   211815         True
# 622                BAG         IV  1807508        True  1807508         True
# 644                BAG         IV  1807508        True  1807508         True
# 687                BAG         IV  1807508        True  1807508         True
# 688                BAG         IV  1807508        True  1807508         True
# 838                 ml         IV   239204        True   239204         True
# 841               VIAL         IV  1721474        True  1721474         True
# ...                ...        ...      ...         ...      ...          ...
# 2708414            BAG         IV  1665212        True  1665212         True
# 2708415            BAG         IV  1807508        True  1807508         True
# 2708429            BAG         IV  1807508        True  1807508         True
# 2708430             mL         IV  1665088        True  1665088         True
# 2708431            BAG         IV  1665212        True  1665212         True
# 2708432            BAG         IV   311683        True   311683         True
# 2708433            BAG         IV  1807508        True  1807508         True
# 2708434              g         IV   313920        True   313920         True
# 2708485           VIAL         IV  1807516        True  1807516         True
# 2708514            BAG         IV  1807508        True  1807508         True
# 2708530            BAG         IV  1807508        True  1807508         True
# 2708540  million units         IV   995906        True   995906         True
# 2708544            BAG         IV  1659151        True  1659151         True
# 2708546           DBTL  RIGHT EAR   309307        True   309307         True
# 2708547            BAG         IV  1659151        True  1659151         True
# 2708550           DBTL  RIGHT EAR   309307        True   309307         True
# 2708551           DBTL  RIGHT EAR   309307        True   309307         True
# 2708563            BAG         IV  1807508        True  1807508         True
# 2708564            BAG         IV  1665046        True  1665046         True
# 2708567            BAG         IV   311683        True   311683         True
# 2708583            BAG         IV  1807508        True  1807508         True
# 2708594           VIAL         IV  1722941        True  1722941         True
# 2708595            BAG         IV  1807508        True  1807508         True
# 2708596           VIAL         IV  1722937        True  1722937         True
# 2708599           VIAL         IV  1722937        True  1722937         True
# 2708648            BAG         IV  1807508        True  1807508         True
# 2708660            BAG         IV  1807508        True  1807508         True
# 2708664            BAG         IV  1807508        True  1807508         True
# 2708678            BAG         IV  1665050        True  1665050         True
# 2708684            BAG         IV   311683        True   311683         True
#
# [129277 rows x 23 columns]
# time: 395 ms
